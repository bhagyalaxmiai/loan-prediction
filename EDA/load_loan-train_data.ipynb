# %%
# database = client['db-customer-churn']
# collection = database['telco-customer-churn']
# data = pd.read_csv("E:\\clarity.ai\\telco-customer-churn\\Telco-customer-churn.csv")
# collection.insert_many(data.to_dict(orient='records'))
# Out:
# InsertManyResult([ObjectId('65eddc68b1633166e2f9a9ce'), ObjectId('65eddc68b1633166e2f9a9cf'), ObjectId('65eddc68b1633166e2f9a9d0'), ObjectId('65eddc68b1633166e2f9a9d1'), ObjectId('65eddc68b1633166e2f9a9d2'), ObjectId('65eddc68b1633166e2f9a9d3'), ObjectId('65eddc68b1633166e2f9a9d4'), ObjectId('65eddc68b1633166e2f9a9d5'), ObjectId('65eddc68b1633166e2f9a9d6'), ObjectId('65eddc68b1633166e2f9a9d7'), ObjectId('65eddc68b1633166e2f9a9d8'), ObjectId('65eddc68b1633166e2f9a9d9'), ObjectId('65eddc68b1633166e2f9a9da'), ObjectId('65eddc68b1633166e2f9a9db'), ObjectId('65eddc68b1633166e2f9a9dc'), ObjectId('65eddc68b1633166e2f9a9dd'), ObjectId('65eddc68b1633166e2f9a9de'), ObjectId('65eddc68b1633166e2f9a9df'), ObjectId('65eddc68b1633166e2f9a9e0'), ObjectId('65eddc68b1633166e2f9a9e1'), ObjectId('65eddc68b1633166e2f9a9e2'), ObjectId('65eddc68b1633166e2f9a9e3'), ObjectId('65eddc68b1633166e2f9a9e4'), ObjectId('65eddc68b1633166e2f9a9e5'), ObjectId('65eddc68b1633166e2f9a9e6'), ObjectId('65eddc68b1633166e2f9
# ...

# %%
# collection = database['telco-customer-churn']

# %%
# collection
# Out:
# Collection(Database(MongoClient(host=['ac-c8q3fc3-shard-00-02.qketnjc.mongodb.net:27017', 'ac-c8q3fc3-shard-00-01.qketnjc.mongodb.net:27017', 'ac-c8q3fc3-shard-00-00.qketnjc.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', tlscafile='isrgrootx1.pem', authsource='admin', replicaset='atlas-bcz8by-shard-0', tls=True), 'db-customer-churn'), 'telco-customer-churn')

# %% [markdown]
# ### Delete all documents from collection

# %%
# collection.delete_many({})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 collection.delete_many({})
#
# NameError: name 'collection' is not defined

# %%
# collection

# %%
# from pymongo.mongo_client import MongoClient

# uri = "mongodb+srv://datawave05:vhR69BnIn434lGwX@datawave.aignamw.mongodb.net/?retryWrites=true&w=majority"

# # Create a new client and connect to the server
# client = MongoClient(uri)

# # Send a ping to confirm a successful connection
# try:
#     client.admin.command('ping')
#     print("Pinged your deployment. You successfully connected to MongoDB!")
# except Exception as e:
#     print(e)
# Out:
# SSL handshake failed: ac-f7aapbc-shard-00-02.aignamw.mongodb.net:27017: [('SSL routines', '', 'certificate verify failed')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-f7aapbc-shard-00-01.aignamw.mongodb.net:27017: [('SSL routines', '', 'certificate verify failed')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-f7aapbc-shard-00-00.aignamw.mongodb.net:27017: [('SSL routines', '', 'certificate verify failed')] (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65f66da9eecea153989776d7, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-f7aapbc-shard-00-00.aignamw.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect("SSL handshake failed: ac-f7aapbc-shard-00-00.aignamw.mongodb.net:27017: [('SSL routines', '', 'certificate verify failed')] (con
# ...

# %%
pip install certifi

# %%
import pandas as pd
import pymongo
from pymongo.mongo_client import MongoClient
# from pymongo.server_api import ServerApi
from pymongo.mongo_client import MongoClient

import certifi
ca = certifi.where()

# pip install certifi
# Create a new client and connect to the server
# client = MongoClient(uri, server_api=ServerApi('1'))
client = MongoClient("mongodb+srv://veenagabnave:aa5xcuda8yrgb6Zd@cluster0.otxvmcd.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0",tlsCAFile=ca)
# client = MongoClient("mongodb+srv://bhagyalaxmi:VSPt0ujgqu2sUKv0@cluster0.qketnjc.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0",tlsCAFile=ca)
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
database = client['loan-prediction']
collection = database['loan-train-data']
data = pd.read_csv("E:\\clarity.ai\\loan-prediction\\loan-train-data.csv")
collection.insert_many(data.to_dict(orient='records'))
# Out:
# InsertManyResult([ObjectId('660cf76b1a89de4c46ce1db6'), ObjectId('660cf76b1a89de4c46ce1db7'), ObjectId('660cf76b1a89de4c46ce1db8'), ObjectId('660cf76b1a89de4c46ce1db9'), ObjectId('660cf76b1a89de4c46ce1dba'), ObjectId('660cf76b1a89de4c46ce1dbb'), ObjectId('660cf76b1a89de4c46ce1dbc'), ObjectId('660cf76b1a89de4c46ce1dbd'), ObjectId('660cf76b1a89de4c46ce1dbe'), ObjectId('660cf76b1a89de4c46ce1dbf'), ObjectId('660cf76b1a89de4c46ce1dc0'), ObjectId('660cf76b1a89de4c46ce1dc1'), ObjectId('660cf76b1a89de4c46ce1dc2'), ObjectId('660cf76b1a89de4c46ce1dc3'), ObjectId('660cf76b1a89de4c46ce1dc4'), ObjectId('660cf76b1a89de4c46ce1dc5'), ObjectId('660cf76b1a89de4c46ce1dc6'), ObjectId('660cf76b1a89de4c46ce1dc7'), ObjectId('660cf76b1a89de4c46ce1dc8'), ObjectId('660cf76b1a89de4c46ce1dc9'), ObjectId('660cf76b1a89de4c46ce1dca'), ObjectId('660cf76b1a89de4c46ce1dcb'), ObjectId('660cf76b1a89de4c46ce1dcc'), ObjectId('660cf76b1a89de4c46ce1dcd'), ObjectId('660cf76b1a89de4c46ce1dce'), ObjectId('660cf76b1a89de4c46ce
# ...

# %%
#  collection.delete_many({})
# Out:
# DeleteResult({'n': 1842, 'electionId': ObjectId('7fffffff0000000000000132'), 'opTime': {'ts': Timestamp(1712125755, 1854), 't': 306}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1712125755, 1857), 'signature': {'hash': b'VT\xcf\xf5N\xfa\x1d\xa9Ea\x93W\xdc\xc2\x8am\xf2\x1b-@', 'keyId': 7312474149799067650}}, 'operationTime': Timestamp(1712125755, 1854)}, acknowledged=True)
